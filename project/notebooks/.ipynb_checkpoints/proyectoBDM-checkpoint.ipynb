# %% [markdown]
# # 🍃 Taller NoSQL — Análisis con SQLite
# **Materia:** Arquitectura de Datos | **Autor:** Daniel Alejandro Garcia | **ID:** 863128
#
# Este notebook consulta `data/almacen.sqlite` generado por el ETL y produce reportes visuales.
#
# > **Prerequisito:** ejecutar `python scripts/02_etl_mongo_sqlite.py` antes de correr este notebook.

# %%
# %matplotlib inline
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import os

# Ruta absoluta al sqlite
BASE = os.path.abspath(os.path.join(os.path.dirname('__file__'), '..'))
SQLITE_PATH = os.path.join(BASE, 'data', 'almacen.sqlite')

# Buscar el archivo
if not os.path.exists(SQLITE_PATH):
    for root, dirs, files in os.walk('/workspaces'):
        for f in files:
            if f == 'almacen.sqlite':
                SQLITE_PATH = os.path.join(root, f)
                break

print('SQLite path:', SQLITE_PATH)
print('Existe:', os.path.exists(SQLITE_PATH))

conn = sqlite3.connect(SQLITE_PATH)
conn.execute('PRAGMA foreign_keys = ON')
print('Conexion a SQLite OK:', SQLITE_PATH)
# Out:
# SQLite path: /workspaces/NoSQL-MongoDB/project/data/almacen.sqlite
# Existe: True
# Conexion a SQLite OK: /workspaces/NoSQL-MongoDB/project/data/almacen.sqlite

# %% [markdown]
# ## 1. Vista general de las tablas

# %%
for tabla in ['personas', 'articulos', 'ventas']:
    df = pd.read_sql_query(f'SELECT * FROM {tabla}', conn)
    print(f'\n--- {tabla} ({len(df)} registros) ---')
    display(df)
# Out:
# --- personas (10 registros) ---
#    numeroDocumento           nombre    telefono
# 0             1001       Juan Perez  3001234567
# 1             1002      Maria Lopez  3109876543
# 2             1003   Carlos Ramirez  3154567890
# 3             1004       Ana Torres  3207654321
# 4             1005     Luis Herrera  3012345678
# 5             1006  Valentina Gomez  3156789012
# 6             1007  Santiago Moreno  3001112233
# 7             1008    Camila Vargas  3204445566
# 8             1009    Andres Castro  3118889900
# 9             1010    Isabella Rios  3167778899
# --- articulos (10 registros) ---
#    idArticulo               nombreArticulo  cantidadArticulo
# 0           1        Laptop Gamer ASUS ROG                 8
# 1           2           Laptop Dell XPS 15                12
# 2           3               MacBook Air M2                15
# 3           4      Monitor LG UltraWide 34                20
# 4           5           Monitor Samsung 27                30
# 5           6   Mouse Logitech MX Master 3                50
# 6           7       Mouse Razer DeathAdder                45
# 7           8          Teclado Corsair K70                25
# 8           9        Teclado Logitech G915                18
# 9          10  Auriculares Sony WH-1000XM5                22
# --- ventas (20 registros) ---
#     idVenta  idComprador  idArticulo  cantidadProductos
# 0         1         1001           1                  1
# 1         2         1001           6                  2
# 2         3         1002           3                  1
# 3         4         1003           2                  3
# 4         5         1003           4                  3
# 5         6         1004          10                  1
# 6         7         1005           8                  2
# 7         8         1006           9                  1
# 8         9         1007           1                  5
# 9        10         1007           5                  5
# 10       11         1008           7                  2
# 11       12         1009           2                  1
# 12       13         1009           4                  1
# 13       14         1010           6                  3
# 14       15         1001           3                  2
# 15       16         1002           8                  1
# 16       17         1005           1                  1
# 17       18         1006          10                  2
# 18       19         1003           6                  5
# 19       20         1004           9                  1

# %% [markdown]
# ## 2. Top 5 artículos más vendidos

# %%
try:
    df_top5 = pd.read_sql_query("""
        SELECT a.nombreArticulo,
               SUM(v.cantidadProductos) AS total_vendido
        FROM ventas v
        JOIN articulos a ON v.idArticulo = a.idArticulo
        GROUP BY v.idArticulo, a.nombreArticulo
        ORDER BY total_vendido DESC
        LIMIT 5
    """, conn)

    plt.figure(figsize=(10, 5))
    plt.bar(df_top5['nombreArticulo'], df_top5['total_vendido'], color='#00ED64')
    plt.title('Top 5 Artículos Más Vendidos', fontsize=14, fontweight='bold')
    plt.xlabel('Artículo')
    plt.ylabel('Cantidad Vendida')
    plt.xticks(rotation=30, ha='right')
    plt.grid(axis='y', alpha=0.3)
    plt.tight_layout()
    plt.show()
    display(df_top5)
except Exception as e:
    print(f'Error: {e}')
finally:
    pass
# Out:
#                nombreArticulo  total_vendido
# 0  Mouse Logitech MX Master 3             10
# 1       Laptop Gamer ASUS ROG              7
# 2          Monitor Samsung 27              5
# 3          Laptop Dell XPS 15              4
# 4     Monitor LG UltraWide 34              4

# %% [markdown]
# ## 3. Top 5 artículos MENOS vendidos (LEFT JOIN + COALESCE)

# %%
try:
    df_menos = pd.read_sql_query("""
        SELECT a.nombreArticulo,
               COALESCE(SUM(v.cantidadProductos), 0) AS total_vendido
        FROM articulos a
        LEFT JOIN ventas v ON a.idArticulo = v.idArticulo
        GROUP BY a.idArticulo
        ORDER BY total_vendido ASC
        LIMIT 5
    """, conn)

    plt.figure(figsize=(10, 5))
    plt.barh(df_menos['nombreArticulo'], df_menos['total_vendido'], color='#F85149')
    plt.title('Top 5 Artículos Menos Vendidos', fontsize=14, fontweight='bold')
    plt.xlabel('Cantidad Vendida')
    plt.ylabel('Artículo')
    plt.grid(axis='x', alpha=0.3)
    plt.tight_layout()
    plt.show()
    display(df_menos)
except Exception as e:
    print(f'Error: {e}')
# Out:
#                 nombreArticulo  total_vendido
# 0       Mouse Razer DeathAdder              2
# 1        Teclado Logitech G915              2
# 2               MacBook Air M2              3
# 3          Teclado Corsair K70              3
# 4  Auriculares Sony WH-1000XM5              3

# %% [markdown]
# ## 4. Top 5 compradores con más compras

# %%
try:
    df_comp = pd.read_sql_query("""
        SELECT p.nombre,
               COUNT(v.idVenta)         AS num_compras,
               SUM(v.cantidadProductos) AS total_productos
        FROM personas p
        JOIN ventas v ON p.numeroDocumento = v.idComprador
        GROUP BY p.numeroDocumento, p.nombre
        ORDER BY num_compras DESC
        LIMIT 5
    """, conn)

    plt.figure(figsize=(10, 5))
    plt.bar(df_comp['nombre'], df_comp['num_compras'], color='#58A6FF')
    plt.title('Top 5 Compradores con Más Compras', fontsize=14, fontweight='bold')
    plt.xlabel('Comprador')
    plt.ylabel('Número de Compras')
    plt.xticks(rotation=20, ha='right')
    plt.grid(axis='y', alpha=0.3)
    plt.tight_layout()
    plt.show()
    display(df_comp)
except Exception as e:
    print(f'Error: {e}')
# Out:
#            nombre  num_compras  total_productos
# 0      Juan Perez            3                5
# 1  Carlos Ramirez            3               11
# 2     Maria Lopez            2                2
# 3      Ana Torres            2                2
# 4    Luis Herrera            2                3

# %% [markdown]
# ## 5. Histograma de distribución de ventas

# %%
try:
    df_hist = pd.read_sql_query(
        'SELECT cantidadProductos FROM ventas', conn)

    plt.figure(figsize=(8, 5))
    plt.hist(df_hist['cantidadProductos'], bins=10, color='#F0B429', edgecolor='black')
    plt.title('Distribución de Ventas por Cantidad', fontsize=14, fontweight='bold')
    plt.xlabel('Cantidad de Productos')
    plt.ylabel('Frecuencia')
    plt.grid(axis='y', alpha=0.3)
    plt.tight_layout()
    plt.show()
except Exception as e:
    print(f'Error: {e}')

# %%
# Cerrar conexion
conn.close()
print('Conexion cerrada.')
# Out:
# Conexion cerrada.
# Bad pipe message: %s [b'6957 HTTP/1.1\r\nAccept: text/html,application/xht']
# Bad pipe message: %s [b'+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7']
# Bad pipe message: %s [b'Host: localh']
# Bad pipe message: %s [b't:44777\r\nUser-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/1', b'.0.0.0 Safari/537.36 Edg/147.0.0.0\r\nAccept-Encoding', b'gzip, deflate, br, zstd\r\nAccept-Language: es-419,es;q=0.9']
# Bad pipe message: %s [b'Referer: htt']
# Bad pipe message: %s [b'://1oleb09p31na9vddn0vl3heurmrvntp12tqs0lar5upa0bgk0emp.assets.github.dev/\r\nX-Request-ID: 970a801ee27697c1413df', b'03de01ca3\r\nX-Real-IP: 47.200.3.132\r\nX-Forwarded-', b'rt: 443\r\nX-Forwarded-Scheme: https\r\nX-Original-URI: /?id=ab0d3589-fe51-4d3b-811', b'0ea25ef3884a&vscodeBrowserReqId=1777572126957\r\nX-Sche', b': https\r\nsec-ch-ua: "Microsoft Edge";v="147", "Not.A/Brand";v="8", "Chromium";v="147"\r\nsec-ch-ua-mobile: ?0\r', b'ec-ch-ua-', b'atform: "Windows"\r\nsec-fetch-site: same-site\r\nsec-fetch-mode: navigate\r\nsec-fetch-dest: iframe\r\npriority: u=0, ']
